# %%
import pandas as pd

df = pd.read_csv("../data/raw_cancer_data.csv", header=None)

# %%
df.head()
# Out:
#          0          1            2             3               4          5   \
# 0        id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 1    842302          M        17.99         10.38           122.8       1001
# 2    842517          M        20.57         17.77           132.9       1326
# 3  84300903          M        19.69         21.25             130       1203
# 4  84348301          M        11.42         20.38           77.58      386.1
#
#                 6                 7               8                    9   \
# 0  smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 1           0.1184            0.2776          0.3001               0.1471
# 2          0.08474           0.07864          0.0869              0.07017
# 3           0.1096            0.1599          0.1974               0.1279
# 4           0.1425            0.2839          0.2414               0.1052
#
#    ...             23               24          25                26  \
# 0  ...  texture_worst  perimeter_worst  area_worst  smoothness_worst
# 1  ...          17.33            184.6        2019            0.1622
# 2  ...          23.41            158.8        1956            0.1238
# 3  ...          25.53            152.5        1709            0.1444
# 4  ...           26.5            98.87       567.7            0.2098
#
#                   27               28                    29              30  \
# 0  compactness_worst  concavity_worst  concave points_worst  symmetry_worst
# 1             0.6656           0.7119                0.2654          0.4601
# 2             0.1866           0.2416                 0.186           0.275
# 3             0.4245           0.4504                 0.243          0.3613
# 4             0.8663           0.6869                0.2575          0.6638
#
#                         31  32
# 0  fractal_dimension_worst NaN
# 1                   0.1189 NaN
# 2                  0.08902 NaN
# 3                  0.08758 NaN
# 4                    0.173 NaN
#
# [5 rows x 33 columns]

# %%
df = df.drop(df.columns[-1], axis=1)

# %%
df = df.drop(index=0).reset_index(drop=True)

# %%
from skimpy import skim

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 569    │ │ string      │ 32    │                                                          │
# │ │ Number of columns │ 32     │ └─────────────┴───────┘                                                          │
# │ └───────────────────┴────────┘                                                                                  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name               ┃ NA      ┃ NA %       ┃ words per row                ┃ total words              ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │                         0 │       0 │          0 │                            1 │                      569 │  │
# │ │                         1 │       0 │          0 │                            1 │                      569 │  │
# │ │                         2 │       0 │          0 │                            1 │                      569 │  │
# │ │                         3 │       0 │          0 │                            1 │                      569 │  │
# │ │                         4 │       0 │          0 │                            1 │                      569 │  │
# │ │                         5 │       0 │          0 │                            1 │                      569 │  │
# │ │                         6 │       0 │          0 │                            1 │                      569 │  │
# │ │                         7 │       0 │          0 │                            1 │                      569 │  │
# │ │                         8 │       0 │          0 │                            1 │                      569 │  │
# │ │                         9 │       0 │          0 │                            1 │                      569 │  │
# │ │                        10 │       0 │          0 │                            1 │                      569 │  │
# │ │                        11 │       0 │          0 │                            1 │                      569 │  │
# │ │                        12 │       0 │          0 │                            1 │                      569 │  │
# │ │                        13 │       0 │          0 │                            1 │                      569 │  │
# │ │                        14 │       0 │          0 │                            1 │                      569 │  │
# │ │                        15 │       0 │          0 │                            1 │                      569 │  │
# │ │                        16 │       0 │          0 │                            1 │                      569 │  │
# │ │                        17 │       0 │          0 │                            1 │                      569 │  │
# │ │                        18 │       0 │          0 │                            1 │                      569 │  │
# │ │                        19 │       0 │          0 │                            1 │                      569 │  │
# │ │                        20 │       0 │          0 │                            1 │                      569 │  │
# │ │                        21 │       0 │          0 │                            1 │                      569 │  │
# │ │                        22 │       0 │          0 │                            1 │                      569 │  │
# │ │                        23 │       0 │          0 │                            1 │                      569 │  │
# │ │                        24 │       0 │          0 │                            1 │                      569 │  │
# │ │                        25 │       0 │          0 │                            1 │                      569 │  │
# │ │                        26 │       0 │          0 │                            1 │                      569 │  │
# │ │                        27 │       0 │          0 │                            1 │                      569 │  │
# │ │                        28 │       0 │          0 │                            1 │                      569 │  │
# │ │                        29 │       0 │          0 │                            1 │                      569 │  │
# │ │                        30 │       0 │          0 │                            1 │                      569 │  │
# │ │                        31 │       0 │          0 │                            1 │                      569 │  │
# │ └───────────────────────────┴─────────┴────────────┴──────────────────────────────┴──────────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df[1] = df[1].map({"M": 1, "B": 0})

# %%
df
# Out:
#            0   1      2      3      4      5        6        7        8   \
# 0      842302   1  17.99  10.38  122.8   1001   0.1184   0.2776   0.3001
# 1      842517   1  20.57  17.77  132.9   1326  0.08474  0.07864   0.0869
# 2    84300903   1  19.69  21.25    130   1203   0.1096   0.1599   0.1974
# 3    84348301   1  11.42  20.38  77.58  386.1   0.1425   0.2839   0.2414
# 4    84358402   1  20.29  14.34  135.1   1297   0.1003   0.1328    0.198
# ..        ...  ..    ...    ...    ...    ...      ...      ...      ...
# 564    926424   1  21.56  22.39    142   1479    0.111   0.1159   0.2439
# 565    926682   1  20.13  28.25  131.2   1261   0.0978   0.1034    0.144
# 566    926954   1   16.6  28.08  108.3  858.1  0.08455   0.1023  0.09251
# 567    927241   1   20.6  29.33  140.1   1265   0.1178    0.277   0.3514
# 568     92751   0   7.76  24.54  47.92    181  0.05263  0.04362        0
#
#           9   ...     22     23     24     25       26       27      28  \
# 0     0.1471  ...  25.38  17.33  184.6   2019   0.1622   0.6656  0.7119
# 1    0.07017  ...  24.99  23.41  158.8   1956   0.1238   0.1866  0.2416
# 2     0.1279  ...  23.57  25.53  152.5   1709   0.1444   0.4245  0.4504
# 3     0.1052  ...  14.91   26.5  98.87  567.7   0.2098   0.8663  0.6869
# 4     0.1043  ...  22.54  16.67  152.2   1575   0.1374    0.205     0.4
# ..       ...  ...    ...    ...    ...    ...      ...      ...     ...
# 564   0.1389  ...  25.45   26.4  166.1   2027    0.141   0.2113  0.4107
# 565  0.09791  ...  23.69  38.25    155   1731   0.1166   0.1922  0.3215
# 566  0.05302  ...  18.98  34.12  126.7   1124   0.1139   0.3094  0.3403
# 567    0.152  ...  25.74  39.42  184.6   1821    0.165   0.8681  0.9387
# 568        0  ...  9.456  30.37  59.16  268.6  0.08996  0.06444       0
#
#          29      30       31
# 0    0.2654  0.4601   0.1189
# 1     0.186   0.275  0.08902
# 2     0.243  0.3613  0.08758
# 3    0.2575  0.6638    0.173
# 4    0.1625  0.2364  0.07678
# ..      ...     ...      ...
# 564  0.2216   0.206  0.07115
# 565  0.1628  0.2572  0.06637
# 566  0.1418  0.2218   0.0782
# 567   0.265  0.4087    0.124
# 568       0  0.2871  0.07039
#
# [569 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
df = df.astype(float)

# %%
# df.to_csv('../data/preprocessed_cancer_data.csv', index=False)

# %%
# Drop the target column (index 1)
X_df = df.drop(columns=[1])

# Calculate the mean and standard deviation for the remaining columns
mean_values = X_df.mean().to_numpy()
std_values = X_df.std().to_numpy()

# %%
statistics = {"mean": mean_values, "std": std_values}

import pickle

# with open('../data/statistics.pkl', 'wb') as f:
#     pickle.dump(statistics, f)


print("Mean values shape:", mean_values.shape)
print("Standard deviation values shape:", std_values.shape)
# Out:
# Mean values shape: (31,)
# Standard deviation values shape: (31,)
